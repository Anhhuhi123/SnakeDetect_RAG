# %% [markdown]
# # Trực quan hóa cho dữ liệu Vietnam_snake(dữ liệu crawl ban đầu)

# %%
import os
import pandas as pd
import random
from PIL import Image
import matplotlib.pyplot as plt

# %%
folder = "Vietnam_snake"
species_list = []

for species_folder in sorted(os.listdir(folder)):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        species_name = species_folder.replace("_", " ")
        print(f"{species_name}: {len(img_files)} ảnh")
        species_list.append(species_name)

print(f"\nTổng số loài: {len(species_list)}")
# Out:
# Achalinus ater: 3 ảnh
# Achalinus rufescens: 334 ảnh
# Achalinus spinalis: 174 ảnh
# Achalinus vanhoensis: 1 ảnh
# Acrochordus granulatus: 429 ảnh
# Acrochordus javanicus: 65 ảnh
# Ahaetulla fusca: 757 ảnh
# Ahaetulla prasina: 1000 ảnh
# Ahaetulla rufusoculara: 75 ảnh
# Amphiesma stolatum: 1000 ảnh
# Archelaphe bella: 21 ảnh
# Argyrophis diardii: 88 ảnh
# Argyrophis siamensis: 3 ảnh
# Azemiops feae: 28 ảnh
# Blue-lipped sea krait: 819 ảnh
# Boiga cyanea: 658 ảnh
# Boiga guangxiensis: 133 ảnh
# Boiga jaspidea: 327 ảnh
# Boiga kraepelini: 1000 ảnh
# Boiga multomaculata: 1000 ảnh
# Boiga siamensis: 270 ảnh
# Bungarus bungaroides: 20 ảnh
# Bungarus candidus: 1000 ảnh
# Bungarus fasciatus: 1000 ảnh
# Bungarus slowinskii: 11 ảnh
# Bungarus wanghaotingi: 135 ảnh
# Calamaria buchi: 8 ảnh
# Calamaria concolor: 11 ảnh
# Calamaria septentrionalis: 239 ảnh
# Calliophis maculiceps: 272 ảnh
# Calloselasma rhodostoma: 1000 ảnh
# Cerberus schneiderii: 1000 ảnh
# Checkered keelback: 1000 ảnh
# Chrysopelea ornata: 1000 ảnh
# Coelognathus flavolineatus: 914 ảnh
# Coelognathus radiatus: 1000 ảnh
# Colubroelaps nguyenvansangi: 3 ảnh
# Cylindrophis jodiae: 565 ảnh
# Cylindrophis ruffus: 350 ảnh
# Deinagkistrodon acutus: 1000 ảnh
# Dendrelaphis biloreatus: 4 ảnh
# Dendrelaphis binhi: 7 ảnh
# Dendrelaphis ngansonensis: 383 ảnh
# Dendrelaphis proarchos: 167 ảnh
# Dendrelaphis subocularis: 268 ảnh
# Dryophiops rubescens: 554 ảnh
# Elaphe carinata: 1000 ảnh
# Elaphe moellendorffi: 88 ảnh
# Elaphe taeniura: 1000 ảnh
# Enhydris enhydris: 1000 ảnh
# Enhydris innominata: 12 ảnh
# Enhydris subtaeniata: 92 ảnh
# Erpeton tentaculatum: 154 ảnh
# Euprepiophis mandarinus: 439 ảnh
# Fimbrios klossi: 37 ảnh
# Fimbrios smithi: 2 ảnh
# Fordonia leucobalia: 289 ảnh
# Fowlea flavipunctata: 1000 ảnh
# Gonyosoma boulengeri: 127 ảnh
# Gonyosoma coeruleum: 228 ảnh
# Gonyosoma frenatum: 178 ảnh
# Gonyosoma oxycephalum: 1000 ảnh
# Hebius andreae: 1 ảnh
# Hebius annamensis: 2 ảnh
# Hebius atemporalis: 38 ảnh
# Hebius bitaeniatus: 33 ảnh
# Hebius boulengeri: 168 ảnh
# Hebius chapaensis: 24 ảnh
# Hebius deschauenseei: 36 ảnh
# Hebius igneus: 6 ảnh
# Hebius khasiensis: 79 ảnh
# Hebius leucomystax: 17 ảnh
# Hebius optatus: 60 ảnh
# Hebius sauteri: 384 ảnh
# Homalopsis mereljcoxi: 304 ảnh
# Hydrophis peronii: 143 ảnh
# Hydrophis viperinus: 4 ảnh
# Hypsiscopus murphyi: 787 ảnh
# Hypsiscopus plumbea: 437 ảnh
# Indotyphlops albiceps: 54 ảnh
# Indotyphlops braminus: 1000 ảnh
# Kuatun keelback: 200 ảnh
# Laticauda colubrina: 1000 ảnh
# Liopeltis frenata: 19 ảnh
# Liopeltis pallidonuchalis: 8 ảnh
# Liopeltis stoliczkae: 3 ảnh
# Lycodon capucinus: 1000 ảnh
# Lycodon cardamomensis: 3 ảnh
# Lycodon chapaensis: 92 ảnh
# Lycodon davisonii: 389 ảnh
# Lycodon fasciatus: 275 ảnh
# Lycodon futsingensis: 596 ảnh
# Lycodon laoensis: 469 ảnh
# Lycodon meridionalis: 134 ảnh
# Lycodon neomaculatus: 325 ảnh
# Lycodon paucifasciatus: 23 ảnh
# Lycodon pictus: 71 ảnh
# Lycodon rufozonatus: 1000 ảnh
# Lycodon ruhstrati: 1000 ảnh
# Lycodon truongi: 97 ảnh
# Malayopython reticulatus: 1000 ảnh
# Microcephalophis gracilis: 5 ảnh
# Myrrophis bennettii: 56 ảnh
# Myrrophis chinensis: 353 ảnh
# Naja atra: 1000 ảnh
# Naja fuxi: 274 ảnh
# Naja siamensis: 530 ảnh
# Oligodon albocinctus: 87 ảnh
# Oligodon annamensis: 3 ảnh
# Oligodon barroni: 88 ảnh
# Oligodon chinensis: 479 ảnh
# Oligodon cinereus: 274 ảnh
# Oligodon culaochamensis: 5 ảnh
# Oligodon cyclurus: 1000 ảnh
# Oligodon deuvei: 84 ảnh
# Oligodon eberhardti: 28 ảnh
# Oligodon fasciolatus: 1000 ảnh
# Oligodon formosanus: 1000 ảnh
# Oligodon lacroixi: 13 ảnh
# Oligodon macrurus: 49 ảnh
# Oligodon nagao: 8 ảnh
# Oligodon ocellatus: 51 ảnh
# Oligodon saintgironsi: 13 ảnh
# Oligodon taeniatus: 429 ảnh
# Oligodon tuani: 25 ảnh
# Ophiophagus hannah: 782 ảnh
# Oreocryptophis porphyraceus: 1000 ảnh
# Ovophis anitae: 12 ảnh
# Ovophis makazayazaya: 537 ảnh
# Ovophis monticola: 852 ảnh
# Ovophis tonkinensis: 391 ảnh
# Parafimbrios lao: 1 ảnh
# Pareas abros: 2 ảnh
# Pareas berdmorei: 543 ảnh
# Pareas carinatus: 1000 ảnh
# Pareas formosensis: 827 ảnh
# Pareas hamptoni: 87 ảnh
# Pareas kuznetsovorum: 1 ảnh
# Pareas macularius: 277 ảnh
# Pareas margaritophorus: 1000 ảnh
# Pareas monticola: 57 ảnh
# Pareas temporalis: 13 ảnh
# Plagiopholis delacouri: 3 ảnh
# Plagiopholis nuchalis: 102 ảnh
# Plagiopholis styani: 40 ảnh
# Pope's keelback: 142 ảnh
# Protobothrops cornutus: 132 ảnh
# Protobothrops jerdonii: 307 ảnh
# Protobothrops maolanensis: 146 ảnh
# Protobothrops mucrosquamatus: 1000 ảnh
# Protobothrops sieversorum: 31 ảnh
# Protobothrops trungkhanhensis: 6 ảnh
# Psammodynastes pulverulentus: 1000 ảnh
# Psammophis indochinensis: 14 ảnh
# Pseudoxenodon bambusicola: 116 ảnh
# Pseudoxenodon karlschmidti: 64 ảnh
# Pseudoxenodon macrops: 583 ảnh
# Ptyas bachmaensis: 12 ảnh
# Ptyas carinata: 534 ảnh
# Ptyas dhumnades: 1000 ảnh
# Ptyas korros: 1000 ảnh
# Ptyas major: 1000 ảnh
# Ptyas mucosa: 1000 ảnh
# Ptyas multicincta: 256 ảnh
# Ptyas nigromarginata: 111 ảnh
# Python bivittatus: 1000 ảnh
# Red-headed krait: 183 ảnh
# Rhabdophis chrysargos: 801 ảnh
# Rhabdophis helleri: 1000 ảnh
# Rhabdophis hmongorum: 16 ảnh
# Rhabdophis nigrocinctus: 270 ảnh
# Rhabdophis nuchalis: 96 ảnh
# Rhabdophis siamensis: 1000 ảnh
# Rhabdophis subminiatus: 1000 ảnh
# Rhabdophis tigrinus: 1000 ảnh
# Sibynophis chinensis: 600 ảnh
# Sibynophis collaris: 835 ảnh
# Sinomicrurus annularis: 431 ảnh
# Sinomicrurus kelloggi: 79 ảnh
# Sinomicrurus macclellandi: 410 ảnh
# Sinomicrurus peinani: 82 ảnh
# Subsessor bocourti: 71 ảnh
# Trimeresurus albolabris: 998 ảnh
# Trimeresurus cardamomensis: 280 ảnh
# Trimeresurus cyanolabris: 33 ảnh
# Trimeresurus guoi: 145 ảnh
# Trimeresurus honsonensis: 67 ảnh
# Trimeresurus rubeus: 554 ảnh
# Trimeresurus stejnegeri: 1000 ảnh
# Trimeresurus truongsonensis: 7 ảnh
# Trimeresurus vogeli: 773 ảnh
# Trimerodytes aequifasciatus: 274 ảnh
# Trimerodytes balteatus: 33 ảnh
# Trimerodytes percarinatus: 1000 ảnh
# Trimerodytes yunnanensis: 26 ảnh
# White-banded wolf snake: 66 ảnh
# Xenopeltis unicolor: 1000 ảnh
#
# Tổng số loài: 197

# %%
image_paths = []

# Lấy tất cả đường dẫn ảnh từ các folder con
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp'))]
        for f in img_files:
            image_paths.append(os.path.join(folder_path, f))

# Chọn 20 ảnh ngẫu nhiên
sample_images = random.sample(image_paths, min(20, len(image_paths)))

# In kích thước của 20 ảnh random
for img_path in sample_images:
    try:
        with Image.open(img_path) as img:
            print(f"{img_path}: {img.width}x{img.height}")
    except Exception as e:
        print(f"Lỗi mở {img_path}: {e}")
# Out:
# Vietnam_snake/Protobothrops_mucrosquamatus/279124259_0.jpg: 946x2048
# Vietnam_snake/Oligodon_taeniatus/255571191_2.jpg: 1536x2048
# Vietnam_snake/Sibynophis_collaris/308963053_1.jpg: 1152x2048
# Vietnam_snake/Ovophis_monticola/236278114_1.jpg: 946x2048
# Vietnam_snake/Fowlea_flavipunctata/301911039_0.jpg: 640x1156
# Vietnam_snake/Ptyas_major/245866008_0.jpg: 1536x2048
# Vietnam_snake/Rhabdophis_tigrinus/250871028_0.jpg: 1715x2048
# Vietnam_snake/Ptyas_carinata/260114736_0.jpg: 2048x1154
# Vietnam_snake/Lycodon_capucinus/304029001_1.jpg: 945x2048
# Vietnam_snake/Hypsiscopus_murphyi/215496839_0.jpg: 2048x1365
# Lỗi mở Vietnam_snake/Rhabdophis_siamensis/130599135_0.jpg: cannot identify image file 'Vietnam_snake/Rhabdophis_siamensis/130599135_0.jpg'
# Vietnam_snake/Ptyas_dhumnades/232007544_0.jpg: 2048x1365
# Vietnam_snake/Bungarus_fasciatus/155570816_0.jpg: 2048x1536
# Vietnam_snake/Ptyas_dhumnades/311686121_0.jpg: 2048x1542
# Vietnam_snake/Laticauda_colubrina/265818760_2.jpg: 2048x1365
# Vietnam_snake/Naja_atra/282570394_1.jpg: 335x283
# Vietnam_snake/Lycodon_laoensis/151146448_1.jpg: 2048x1536
# Vietnam_snake/Hydrophis_peronii/284801970_0.jpg: 2048x1536
# Vietnam_snake/Euprepiophis_mandarinus/176284032_0.jpg: 1620x1080
# Vietnam_snake/Calamaria_septentrionalis/216466074_3.jpg: 2048x1365

# %%
# Tạo bins tự động với bước nhảy 50
max_count = 0
counts = []
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        counts.append(len(img_files))
        if len(img_files) > max_count:
            max_count = len(img_files)

step = 50
bins = list(range(0, max_count + step, step))
labels = [f"{bins[i]+1}-{bins[i+1]}" for i in range(len(bins)-1)]

# Gom số loài vào từng khoảng
hist = [0] * (len(bins) - 1)
for c in counts:
    for i in range(len(bins) - 1):
        if bins[i] < c <= bins[i+1]:
            hist[i] += 1
            break

plt.bar(labels, hist)
plt.xlabel("Khoảng số lượng ảnh mỗi loài")
plt.ylabel("Số loài")
plt.title("Phân bố số lượng ảnh các loài rắn")
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Trực quan hóa cho dữ liệu Vietnam_snake_1024px(sau khi bỏ những loài dưới 50 ảnh)

# %%
folder = "Vietnam_snake_1024px"
species_list = []

for species_folder in sorted(os.listdir(folder)):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        species_name = species_folder.replace("_", " ")
        print(f"{species_name}: {len(img_files)} ảnh")
        species_list.append(species_name)

print(f"\nTổng số loài: {len(species_list)}")
# Out:
# Achalinus rufescens: 333 ảnh
# Achalinus spinalis: 174 ảnh
# Acrochordus granulatus: 425 ảnh
# Acrochordus javanicus: 65 ảnh
# Ahaetulla fusca: 757 ảnh
# Ahaetulla prasina: 999 ảnh
# Ahaetulla rufusoculara: 75 ảnh
# Amphiesma stolatum: 997 ảnh
# Argyrophis diardii: 88 ảnh
# Blue-lipped sea krait: 814 ảnh
# Boiga cyanea: 654 ảnh
# Boiga guangxiensis: 133 ảnh
# Boiga jaspidea: 325 ảnh
# Boiga kraepelini: 993 ảnh
# Boiga multomaculata: 997 ảnh
# Boiga siamensis: 270 ảnh
# Bungarus candidus: 1000 ảnh
# Bungarus fasciatus: 997 ảnh
# Bungarus wanghaotingi: 135 ảnh
# Calamaria septentrionalis: 238 ảnh
# Calliophis maculiceps: 268 ảnh
# Calloselasma rhodostoma: 998 ảnh
# Cerberus schneiderii: 993 ảnh
# Checkered keelback: 999 ảnh
# Chrysopelea ornata: 1000 ảnh
# Coelognathus flavolineatus: 913 ảnh
# Coelognathus radiatus: 993 ảnh
# Cylindrophis jodiae: 562 ảnh
# Cylindrophis ruffus: 350 ảnh
# Deinagkistrodon acutus: 997 ảnh
# Dendrelaphis ngansonensis: 378 ảnh
# Dendrelaphis proarchos: 165 ảnh
# Dendrelaphis subocularis: 268 ảnh
# Dryophiops rubescens: 411 ảnh
# Elaphe carinata: 883 ảnh
# Elaphe moellendorffi: 88 ảnh
# Elaphe taeniura: 998 ảnh
# Enhydris enhydris: 998 ảnh
# Enhydris subtaeniata: 92 ảnh
# Erpeton tentaculatum: 154 ảnh
# Euprepiophis mandarinus: 436 ảnh
# Fordonia leucobalia: 289 ảnh
# Fowlea flavipunctata: 996 ảnh
# Gonyosoma boulengeri: 124 ảnh
# Gonyosoma coeruleum: 228 ảnh
# Gonyosoma frenatum: 177 ảnh
# Gonyosoma oxycephalum: 993 ảnh
# Hebius boulengeri: 168 ảnh
# Hebius khasiensis: 79 ảnh
# Hebius optatus: 60 ảnh
# Hebius sauteri: 383 ảnh
# Homalopsis mereljcoxi: 304 ảnh
# Hydrophis peronii: 139 ảnh
# Hypsiscopus murphyi: 785 ảnh
# Hypsiscopus plumbea: 436 ảnh
# Indotyphlops albiceps: 53 ảnh
# Indotyphlops braminus: 1000 ảnh
# Kuatun keelback: 200 ảnh
# Laticauda colubrina: 961 ảnh
# Lycodon capucinus: 1000 ảnh
# Lycodon chapaensis: 92 ảnh
# Lycodon davisonii: 387 ảnh
# Lycodon fasciatus: 273 ảnh
# Lycodon futsingensis: 591 ảnh
# Lycodon laoensis: 468 ảnh
# Lycodon meridionalis: 131 ảnh
# Lycodon neomaculatus: 323 ảnh
# Lycodon pictus: 71 ảnh
# Lycodon rufozonatus: 1000 ảnh
# Lycodon ruhstrati: 999 ảnh
# Lycodon truongi: 96 ảnh
# Malayopython reticulatus: 996 ảnh
# Myrrophis bennettii: 56 ảnh
# Myrrophis chinensis: 350 ảnh
# Naja atra: 999 ảnh
# Naja fuxi: 255 ảnh
# Naja siamensis: 526 ảnh
# Oligodon albocinctus: 87 ảnh
# Oligodon barroni: 88 ảnh
# Oligodon chinensis: 479 ảnh
# Oligodon cinereus: 274 ảnh
# Oligodon cyclurus: 1000 ảnh
# Oligodon deuvei: 84 ảnh
# Oligodon fasciolatus: 1000 ảnh
# Oligodon formosanus: 1000 ảnh
# Oligodon ocellatus: 51 ảnh
# Oligodon taeniatus: 429 ảnh
# Ophiophagus hannah: 770 ảnh
# Oreocryptophis porphyraceus: 1000 ảnh
# Ovophis makazayazaya: 537 ảnh
# Ovophis monticola: 692 ảnh
# Ovophis tonkinensis: 387 ảnh
# Pareas berdmorei: 542 ảnh
# Pareas carinatus: 999 ảnh
# Pareas formosensis: 825 ảnh
# Pareas hamptoni: 87 ảnh
# Pareas macularius: 277 ảnh
# Pareas margaritophorus: 844 ảnh
# Pareas monticola: 57 ảnh
# Plagiopholis nuchalis: 101 ảnh
# Pope's keelback: 142 ảnh
# Protobothrops cornutus: 132 ảnh
# Protobothrops jerdonii: 306 ảnh
# Protobothrops maolanensis: 146 ảnh
# Protobothrops mucrosquamatus: 1000 ảnh
# Psammodynastes pulverulentus: 1000 ảnh
# Pseudoxenodon bambusicola: 116 ảnh
# Pseudoxenodon karlschmidti: 64 ảnh
# Pseudoxenodon macrops: 579 ảnh
# Ptyas carinata: 525 ảnh
# Ptyas dhumnades: 994 ảnh
# Ptyas korros: 999 ảnh
# Ptyas major: 1000 ảnh
# Ptyas mucosa: 1000 ảnh
# Ptyas multicincta: 254 ảnh
# Ptyas nigromarginata: 111 ảnh
# Python bivittatus: 994 ảnh
# Red-headed krait: 180 ảnh
# Rhabdophis chrysargos: 801 ảnh
# Rhabdophis helleri: 789 ảnh
# Rhabdophis nigrocinctus: 191 ảnh
# Rhabdophis nuchalis: 78 ảnh
# Rhabdophis siamensis: 578 ảnh
# Rhabdophis subminiatus: 685 ảnh
# Rhabdophis tigrinus: 647 ảnh
# Sibynophis chinensis: 424 ảnh
# Sibynophis collaris: 596 ảnh
# Sinomicrurus annularis: 345 ảnh
# Sinomicrurus kelloggi: 58 ảnh
# Sinomicrurus macclellandi: 255 ảnh
# Sinomicrurus peinani: 70 ảnh
# Subsessor bocourti: 53 ảnh
# Trimeresurus albolabris: 664 ảnh
# Trimeresurus cardamomensis: 210 ảnh
# Trimeresurus guoi: 118 ảnh
# Trimeresurus rubeus: 354 ảnh
# Trimeresurus stejnegeri: 712 ảnh
# Trimeresurus vogeli: 545 ảnh
# Trimerodytes aequifasciatus: 180 ảnh
# Trimerodytes percarinatus: 616 ảnh
# White-banded wolf snake: 52 ảnh
# Xenopeltis unicolor: 613 ảnh
#
# Tổng số loài: 142

# %%
image_paths = []

# Lấy tất cả đường dẫn ảnh từ các folder con
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp'))]
        for f in img_files:
            image_paths.append(os.path.join(folder_path, f))

# Chọn 20 ảnh ngẫu nhiên
sample_images = random.sample(image_paths, min(20, len(image_paths)))

# In kích thước của 20 ảnh random
for img_path in sample_images:
    try:
        with Image.open(img_path) as img:
            print(f"{img_path}: {img.width}x{img.height}")
    except Exception as e:
        print(f"Lỗi mở {img_path}: {e}")
# Out:
# Vietnam_snake_1024px/Ahaetulla_fusca/249162999_2.jpg: 1024x1024
# Vietnam_snake_1024px/Rhabdophis_helleri/181395944_0.jpg: 1024x1024
# Vietnam_snake_1024px/Oreocryptophis_porphyraceus/281805878_3.jpg: 1024x1024
# Vietnam_snake_1024px/Xenopeltis_unicolor/236852035_3.jpg: 1024x1024
# Vietnam_snake_1024px/Oligodon_fasciolatus/278234500_0.jpg: 1024x1024
# Vietnam_snake_1024px/Laticauda_colubrina/286258169_0.jpg: 1024x1024
# Vietnam_snake_1024px/Myrrophis_bennettii/271388086_2.jpg: 1024x1024
# Vietnam_snake_1024px/Xenopeltis_unicolor/235133159_2.jpg: 1024x1024
# Vietnam_snake_1024px/Oligodon_formosanus/296679420_0.jpg: 1024x1024
# Vietnam_snake_1024px/Oligodon_fasciolatus/192294905_0.jpg: 1024x1024
# Vietnam_snake_1024px/Oligodon_formosanus/181709054_0.jpg: 1024x1024
# Vietnam_snake_1024px/Bungarus_fasciatus/295542715_0.jpg: 1024x1024
# Vietnam_snake_1024px/Sinomicrurus_annularis/94343548_0.jpg: 1024x1024
# Vietnam_snake_1024px/Oligodon_fasciolatus/187901087_2.jpg: 1024x1024
# Vietnam_snake_1024px/Ahaetulla_prasina/280209099_0.jpg: 1024x1024
# Vietnam_snake_1024px/Trimeresurus_stejnegeri/313356633_1.jpg: 1024x1024
# Vietnam_snake_1024px/Chrysopelea_ornata/311902120_2.jpg: 1024x1024
# Vietnam_snake_1024px/Ahaetulla_fusca/308201196_1.jpg: 1024x1024
# Vietnam_snake_1024px/Trimeresurus_albolabris/266063406_1.jpg: 1024x1024
# Vietnam_snake_1024px/Ptyas_major/300880719_4.jpg: 1024x1024

# %%
# Tạo bins tự động với bước nhảy 50
max_count = 0
counts = []
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        counts.append(len(img_files))
        if len(img_files) > max_count:
            max_count = len(img_files)

step = 50
bins = list(range(0, max_count + step, step))
labels = [f"{bins[i]+1}-{bins[i+1]}" for i in range(len(bins)-1)]

# Gom số loài vào từng khoảng
hist = [0] * (len(bins) - 1)
for c in counts:
    for i in range(len(bins) - 1):
        if bins[i] < c <= bins[i+1]:
            hist[i] += 1
            break

plt.bar(labels, hist)
plt.xlabel("Khoảng số lượng ảnh mỗi loài")
plt.ylabel("Số loài")
plt.title("Phân bố số lượng ảnh các loài rắn")
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Trực quan hóa cho dữ liệu Vietnam_snake_1024px_detect

# %%
folder = "Vietnam_snake_1024px_detect"
species_list = []

for species_folder in sorted(os.listdir(folder)):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        species_name = species_folder.replace("_", " ")
        print(f"{species_name}: {len(img_files)} ảnh")
        species_list.append(species_name)

print(f"\nTổng số loài: {len(species_list)}")
# Out:
# Achalinus rufescens: 398 ảnh
# Achalinus spinalis: 208 ảnh
# Acrochordus granulatus: 450 ảnh
# Acrochordus javanicus: 60 ảnh
# Ahaetulla fusca: 633 ảnh
# Ahaetulla prasina: 907 ảnh
# Ahaetulla rufusoculara: 86 ảnh
# Amphiesma stolatum: 1164 ảnh
# Argyrophis diardii: 105 ảnh
# Blue-lipped sea krait: 974 ảnh
# Boiga cyanea: 845 ảnh
# Boiga guangxiensis: 167 ảnh
# Boiga jaspidea: 424 ảnh
# Boiga kraepelini: 1163 ảnh
# Boiga multomaculata: 1288 ảnh
# Boiga siamensis: 347 ảnh
# Bungarus candidus: 1129 ảnh
# Bungarus fasciatus: 1145 ảnh
# Bungarus wanghaotingi: 168 ảnh
# Calamaria septentrionalis: 321 ảnh
# Calliophis maculiceps: 340 ảnh
# Calloselasma rhodostoma: 1120 ảnh
# Cerberus schneiderii: 1239 ảnh
# Checkered keelback: 1154 ảnh
# Chrysopelea ornata: 1259 ảnh
# Coelognathus flavolineatus: 1133 ảnh
# Coelognathus radiatus: 1211 ảnh
# Cylindrophis jodiae: 659 ảnh
# Cylindrophis ruffus: 436 ảnh
# Deinagkistrodon acutus: 1130 ảnh
# Dendrelaphis ngansonensis: 468 ảnh
# Dendrelaphis proarchos: 211 ảnh
# Dendrelaphis subocularis: 341 ảnh
# Dryophiops rubescens: 500 ảnh
# Elaphe carinata: 1010 ảnh
# Elaphe moellendorffi: 101 ảnh
# Elaphe taeniura: 1227 ảnh
# Enhydris enhydris: 1152 ảnh
# Enhydris subtaeniata: 120 ảnh
# Erpeton tentaculatum: 188 ảnh
# Euprepiophis mandarinus: 513 ảnh
# Fordonia leucobalia: 350 ảnh
# Fowlea flavipunctata: 1138 ảnh
# Gonyosoma boulengeri: 140 ảnh
# Gonyosoma coeruleum: 240 ảnh
# Gonyosoma frenatum: 216 ảnh
# Gonyosoma oxycephalum: 1093 ảnh
# Hebius boulengeri: 208 ảnh
# Hebius khasiensis: 98 ảnh
# Hebius optatus: 81 ảnh
# Hebius sauteri: 462 ảnh
# Homalopsis mereljcoxi: 387 ảnh
# Hydrophis peronii: 150 ảnh
# Hypsiscopus murphyi: 922 ảnh
# Hypsiscopus plumbea: 528 ảnh
# Indotyphlops albiceps: 65 ảnh
# Indotyphlops braminus: 1125 ảnh
# Kuatun keelback: 234 ảnh
# Laticauda colubrina: 1046 ảnh
# Lycodon capucinus: 1249 ảnh
# Lycodon chapaensis: 122 ảnh
# Lycodon davisonii: 473 ảnh
# Lycodon fasciatus: 338 ảnh
# Lycodon futsingensis: 699 ảnh
# Lycodon laoensis: 577 ảnh
# Lycodon meridionalis: 170 ảnh
# Lycodon neomaculatus: 392 ảnh
# Lycodon pictus: 80 ảnh
# Lycodon rufozonatus: 1194 ảnh
# Lycodon ruhstrati: 1241 ảnh
# Lycodon truongi: 104 ảnh
# Malayopython reticulatus: 1135 ảnh
# Myrrophis bennettii: 89 ảnh
# Myrrophis chinensis: 384 ảnh
# Naja atra: 1163 ảnh
# Naja fuxi: 305 ảnh
# Naja siamensis: 631 ảnh
# Oligodon albocinctus: 101 ảnh
# Oligodon barroni: 107 ảnh
# Oligodon chinensis: 609 ảnh
# Oligodon cinereus: 330 ảnh
# Oligodon cyclurus: 1133 ảnh
# Oligodon deuvei: 105 ảnh
# Oligodon fasciolatus: 1134 ảnh
# Oligodon formosanus: 1250 ảnh
# Oligodon ocellatus: 60 ảnh
# Oligodon taeniatus: 507 ảnh
# Ophiophagus hannah: 882 ảnh
# Oreocryptophis porphyraceus: 1219 ảnh
# Ovophis makazayazaya: 647 ảnh
# Ovophis monticola: 843 ảnh
# Ovophis tonkinensis: 471 ảnh
# Pareas berdmorei: 693 ảnh
# Pareas carinatus: 1321 ảnh
# Pareas formosensis: 1070 ảnh
# Pareas hamptoni: 119 ảnh
# Pareas macularius: 353 ảnh
# Pareas margaritophorus: 1084 ảnh
# Pareas monticola: 79 ảnh
# Plagiopholis nuchalis: 110 ảnh
# Pope's keelback: 170 ảnh
# Protobothrops cornutus: 147 ảnh
# Protobothrops jerdonii: 377 ảnh
# Protobothrops maolanensis: 192 ảnh
# Protobothrops mucrosquamatus: 1145 ảnh
# Psammodynastes pulverulentus: 1206 ảnh
# Pseudoxenodon bambusicola: 139 ảnh
# Pseudoxenodon karlschmidti: 77 ảnh
# Pseudoxenodon macrops: 670 ảnh
# Ptyas carinata: 544 ảnh
# Ptyas dhumnades: 1182 ảnh
# Ptyas korros: 1231 ảnh
# Ptyas major: 1109 ảnh
# Ptyas mucosa: 1120 ảnh
# Ptyas multicincta: 308 ảnh
# Ptyas nigromarginata: 131 ảnh
# Python bivittatus: 1171 ảnh
# Red-headed krait: 213 ảnh
# Rhabdophis chrysargos: 926 ảnh
# Rhabdophis helleri: 983 ảnh
# Rhabdophis nigrocinctus: 222 ảnh
# Rhabdophis nuchalis: 95 ảnh
# Rhabdophis siamensis: 623 ảnh
# Rhabdophis subminiatus: 842 ảnh
# Rhabdophis tigrinus: 730 ảnh
# Sibynophis chinensis: 483 ảnh
# Sibynophis collaris: 699 ảnh
# Sinomicrurus annularis: 451 ảnh
# Sinomicrurus kelloggi: 74 ảnh
# Sinomicrurus macclellandi: 302 ảnh
# Sinomicrurus peinani: 78 ảnh
# Subsessor bocourti: 62 ảnh
# Trimeresurus albolabris: 791 ảnh
# Trimeresurus cardamomensis: 224 ảnh
# Trimeresurus guoi: 155 ảnh
# Trimeresurus rubeus: 426 ảnh
# Trimeresurus stejnegeri: 836 ảnh
# Trimeresurus vogeli: 563 ảnh
# Trimerodytes aequifasciatus: 224 ảnh
# Trimerodytes percarinatus: 706 ảnh
# White-banded wolf snake: 59 ảnh
# Xenopeltis unicolor: 724 ảnh
#
# Tổng số loài: 142

# %%
image_paths = []

# Lấy tất cả đường dẫn ảnh từ các folder con
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp'))]
        for f in img_files:
            image_paths.append(os.path.join(folder_path, f))

# Chọn 20 ảnh ngẫu nhiên
sample_images = random.sample(image_paths, min(20, len(image_paths)))

# In kích thước của 20 ảnh random
for img_path in sample_images:
    try:
        with Image.open(img_path) as img:
            print(f"{img_path}: {img.width}x{img.height}")
    except Exception as e:
        print(f"Lỗi mở {img_path}: {e}")
# Out:
# Vietnam_snake_1024px_detect/Gonyosoma_oxycephalum/266928838_02.jpg: 892x729
# Vietnam_snake_1024px_detect/Pareas_carinatus/102537267_0.jpg: 642x620
# Vietnam_snake_1024px_detect/Coelognathus_flavolineatus/72668618_12.jpg: 1024x130
# Vietnam_snake_1024px_detect/Rhabdophis_tigrinus/248225513_62.jpg: 513x796
# Vietnam_snake_1024px_detect/Oreocryptophis_porphyraceus/101379192_0.jpg: 747x340
# Vietnam_snake_1024px_detect/Amphiesma_stolatum/243782667_5.jpg: 906x1016
# Vietnam_snake_1024px_detect/Oreocryptophis_porphyraceus/277260131_9.jpg: 846x830
# Vietnam_snake_1024px_detect/Lycodon_neomaculatus/294344142_0.jpg: 759x393
# Vietnam_snake_1024px_detect/Pareas_carinatus/62131879_0.jpg: 321x292
# Vietnam_snake_1024px_detect/Oligodon_fasciolatus/203762781_0.jpg: 905x802
# Vietnam_snake_1024px_detect/Enhydris_enhydris/301244464_32.jpg: 894x427
# Vietnam_snake_1024px_detect/Laticauda_colubrina/231866999_2.jpg: 455x640
# Vietnam_snake_1024px_detect/Sibynophis_chinensis/4639353_3.jpg: 964x986
# Vietnam_snake_1024px_detect/Naja_atra/228450202_1.jpg: 875x812
# Vietnam_snake_1024px_detect/Ovophis_makazayazaya/212536690_0.jpg: 686x604
# Vietnam_snake_1024px_detect/Ptyas_korros/269587587_1.jpg: 936x190
# Vietnam_snake_1024px_detect/Sibynophis_collaris/218539490_0.jpg: 832x754
# Vietnam_snake_1024px_detect/Pseudoxenodon_macrops/251886153_0.jpg: 667x359
# Vietnam_snake_1024px_detect/Indotyphlops_braminus/311211260_2.jpg: 586x1019
# Vietnam_snake_1024px_detect/Dryophiops_rubescens/239363458_22.jpg: 679x956

# %%
# Tạo bins tự động với bước nhảy 50
max_count = 0
counts = []
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        counts.append(len(img_files))
        if len(img_files) > max_count:
            max_count = len(img_files)

step = 50
bins = list(range(0, max_count + step, step))
labels = [f"{bins[i]+1}-{bins[i+1]}" for i in range(len(bins)-1)]

# Gom số loài vào từng khoảng
hist = [0] * (len(bins) - 1)
for c in counts:
    for i in range(len(bins) - 1):
        if bins[i] < c <= bins[i+1]:
            hist[i] += 1
            break

plt.bar(labels, hist)
plt.xlabel("Khoảng số lượng ảnh mỗi loài")
plt.ylabel("Số loài")
plt.title("Phân bố số lượng ảnh các loài rắn")
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Trực quan hóa cho dữ liệu Vietnam_snake_224px(sau khi loại bỏ ảnh dưới 200x200px và resize về 224px)

# %%
folder = "Vietnam_snake_224px"
species_list = []

for species_folder in sorted(os.listdir(folder)):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        species_name = species_folder.replace("_", " ")
        print(f"{species_name}: {len(img_files)} ảnh")
        species_list.append(species_name)

print(f"\nTổng số loài: {len(species_list)}")
# Out:
# Achalinus rufescens: 367 ảnh
# Achalinus spinalis: 190 ảnh
# Acrochordus granulatus: 397 ảnh
# Acrochordus javanicus: 56 ảnh
# Ahaetulla fusca: 484 ảnh
# Ahaetulla prasina: 694 ảnh
# Ahaetulla rufusoculara: 71 ảnh
# Amphiesma stolatum: 980 ảnh
# Argyrophis diardii: 90 ảnh
# Blue-lipped sea krait: 830 ảnh
# Boiga cyanea: 727 ảnh
# Boiga guangxiensis: 152 ảnh
# Boiga jaspidea: 367 ảnh
# Boiga kraepelini: 1001 ảnh
# Boiga multomaculata: 1132 ảnh
# Boiga siamensis: 314 ảnh
# Bungarus candidus: 932 ảnh
# Bungarus fasciatus: 1021 ảnh
# Bungarus wanghaotingi: 134 ảnh
# Calamaria septentrionalis: 283 ảnh
# Calliophis maculiceps: 294 ảnh
# Calloselasma rhodostoma: 1012 ảnh
# Cerberus schneiderii: 964 ảnh
# Checkered keelback: 904 ảnh
# Chrysopelea ornata: 983 ảnh
# Coelognathus flavolineatus: 965 ảnh
# Coelognathus radiatus: 1032 ảnh
# Cylindrophis jodiae: 580 ảnh
# Cylindrophis ruffus: 394 ảnh
# Deinagkistrodon acutus: 991 ảnh
# Dendrelaphis ngansonensis: 403 ảnh
# Dendrelaphis proarchos: 174 ảnh
# Dendrelaphis subocularis: 274 ảnh
# Dryophiops rubescens: 419 ảnh
# Elaphe carinata: 870 ảnh
# Elaphe moellendorffi: 86 ảnh
# Elaphe taeniura: 1010 ảnh
# Enhydris enhydris: 957 ảnh
# Enhydris subtaeniata: 109 ảnh
# Erpeton tentaculatum: 162 ảnh
# Euprepiophis mandarinus: 448 ảnh
# Fordonia leucobalia: 327 ảnh
# Fowlea flavipunctata: 945 ảnh
# Gonyosoma boulengeri: 109 ảnh
# Gonyosoma coeruleum: 217 ảnh
# Gonyosoma frenatum: 185 ảnh
# Gonyosoma oxycephalum: 882 ảnh
# Hebius boulengeri: 190 ảnh
# Hebius khasiensis: 95 ảnh
# Hebius optatus: 74 ảnh
# Hebius sauteri: 424 ảnh
# Homalopsis mereljcoxi: 338 ảnh
# Hydrophis peronii: 125 ảnh
# Hypsiscopus murphyi: 812 ảnh
# Hypsiscopus plumbea: 446 ảnh
# Indotyphlops albiceps: 52 ảnh
# Indotyphlops braminus: 942 ảnh
# Kuatun keelback: 221 ảnh
# Laticauda colubrina: 926 ảnh
# Lycodon capucinus: 1112 ảnh
# Lycodon chapaensis: 110 ảnh
# Lycodon davisonii: 390 ảnh
# Lycodon fasciatus: 304 ảnh
# Lycodon futsingensis: 623 ảnh
# Lycodon laoensis: 509 ảnh
# Lycodon meridionalis: 147 ảnh
# Lycodon neomaculatus: 338 ảnh
# Lycodon pictus: 78 ảnh
# Lycodon rufozonatus: 1020 ảnh
# Lycodon ruhstrati: 1063 ảnh
# Lycodon truongi: 88 ảnh
# Malayopython reticulatus: 945 ảnh
# Myrrophis bennettii: 79 ảnh
# Myrrophis chinensis: 332 ảnh
# Naja atra: 1021 ảnh
# Naja fuxi: 267 ảnh
# Naja siamensis: 573 ảnh
# Oligodon albocinctus: 93 ảnh
# Oligodon barroni: 97 ảnh
# Oligodon chinensis: 555 ảnh
# Oligodon cinereus: 296 ảnh
# Oligodon cyclurus: 977 ảnh
# Oligodon deuvei: 103 ảnh
# Oligodon fasciolatus: 986 ảnh
# Oligodon formosanus: 1081 ảnh
# Oligodon ocellatus: 53 ảnh
# Oligodon taeniatus: 445 ảnh
# Ophiophagus hannah: 738 ảnh
# Oreocryptophis porphyraceus: 1090 ảnh
# Ovophis makazayazaya: 597 ảnh
# Ovophis monticola: 785 ảnh
# Ovophis tonkinensis: 442 ảnh
# Pareas berdmorei: 621 ảnh
# Pareas carinatus: 1157 ảnh
# Pareas formosensis: 938 ảnh
# Pareas hamptoni: 107 ảnh
# Pareas macularius: 328 ảnh
# Pareas margaritophorus: 968 ảnh
# Pareas monticola: 72 ảnh
# Plagiopholis nuchalis: 99 ảnh
# Pope's keelback: 164 ảnh
# Protobothrops cornutus: 142 ảnh
# Protobothrops jerdonii: 321 ảnh
# Protobothrops maolanensis: 183 ảnh
# Protobothrops mucrosquamatus: 962 ảnh
# Psammodynastes pulverulentus: 1016 ảnh
# Pseudoxenodon bambusicola: 124 ảnh
# Pseudoxenodon karlschmidti: 71 ảnh
# Pseudoxenodon macrops: 601 ảnh
# Ptyas carinata: 448 ảnh
# Ptyas dhumnades: 960 ảnh
# Ptyas korros: 1023 ảnh
# Ptyas major: 935 ảnh
# Ptyas mucosa: 887 ảnh
# Ptyas multicincta: 271 ảnh
# Ptyas nigromarginata: 102 ảnh
# Python bivittatus: 990 ảnh
# Red-headed krait: 175 ảnh
# Rhabdophis chrysargos: 825 ảnh
# Rhabdophis helleri: 828 ảnh
# Rhabdophis nigrocinctus: 192 ảnh
# Rhabdophis nuchalis: 88 ảnh
# Rhabdophis siamensis: 526 ảnh
# Rhabdophis subminiatus: 710 ảnh
# Rhabdophis tigrinus: 598 ảnh
# Sibynophis chinensis: 432 ảnh
# Sibynophis collaris: 615 ảnh
# Sinomicrurus annularis: 399 ảnh
# Sinomicrurus kelloggi: 69 ảnh
# Sinomicrurus macclellandi: 270 ảnh
# Sinomicrurus peinani: 69 ảnh
# Subsessor bocourti: 61 ảnh
# Trimeresurus albolabris: 662 ảnh
# Trimeresurus cardamomensis: 207 ảnh
# Trimeresurus guoi: 137 ảnh
# Trimeresurus rubeus: 381 ảnh
# Trimeresurus stejnegeri: 673 ảnh
# Trimeresurus vogeli: 486 ảnh
# Trimerodytes aequifasciatus: 191 ảnh
# Trimerodytes percarinatus: 564 ảnh
# White-banded wolf snake: 57 ảnh
# Xenopeltis unicolor: 675 ảnh
#
# Tổng số loài: 142

# %%
image_paths = []

# Lấy tất cả đường dẫn ảnh từ các folder con
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp'))]
        for f in img_files:
            image_paths.append(os.path.join(folder_path, f))

# Chọn 20 ảnh ngẫu nhiên
sample_images = random.sample(image_paths, min(20, len(image_paths)))

# In kích thước của 20 ảnh random
for img_path in sample_images:
    try:
        with Image.open(img_path) as img:
            print(f"{img_path}: {img.width}x{img.height}")
    except Exception as e:
        print(f"Lỗi mở {img_path}: {e}")
# Out:
# Vietnam_snake_224px/Sibynophis_collaris/4639353_18.jpg: 224x224
# Vietnam_snake_224px/Acrochordus_granulatus/71574003_36.jpg: 224x224
# Vietnam_snake_224px/Oligodon_cyclurus/249132974_0.jpg: 224x224
# Vietnam_snake_224px/Elaphe_taeniura/282831892_0.jpg: 224x224
# Vietnam_snake_224px/Rhabdophis_chrysargos/247078945_0.jpg: 224x224
# Vietnam_snake_224px/Coelognathus_radiatus/146442719_12.jpg: 224x224
# Vietnam_snake_224px/Lycodon_davisonii/13579559_0.jpg: 224x224
# Vietnam_snake_224px/Fowlea_flavipunctata/240329806_22.jpg: 224x224
# Vietnam_snake_224px/Boiga_kraepelini/308616956_02.jpg: 224x224
# Vietnam_snake_224px/Pareas_margaritophorus/128384805_1.jpg: 224x224
# Vietnam_snake_224px/Oreocryptophis_porphyraceus/228144448_92.jpg: 224x224
# Vietnam_snake_224px/Bungarus_candidus/306443816_0.jpg: 224x224
# Vietnam_snake_224px/Bungarus_fasciatus/248200588_42.jpg: 224x224
# Vietnam_snake_224px/Rhabdophis_subminiatus/195877702_12.jpg: 224x224
# Vietnam_snake_224px/Dendrelaphis_ngansonensis/63555675_0.jpg: 224x224
# Vietnam_snake_224px/Ptyas_major/288665790_1.jpg: 224x224
# Vietnam_snake_224px/Red-headed_krait/27484379_0.jpg: 224x224
# Vietnam_snake_224px/Boiga_kraepelini/285009437_12.jpg: 224x224
# Vietnam_snake_224px/Oligodon_formosanus/183309544_4.jpg: 224x224
# Vietnam_snake_224px/Hypsiscopus_plumbea/198666458_0.jpg: 224x224

# %%
# Tạo bins tự động với bước nhảy 50
max_count = 0
counts = []
for species_folder in os.listdir(folder):
    folder_path = os.path.join(folder, species_folder)
    if os.path.isdir(folder_path):
        img_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp'))]
        counts.append(len(img_files))
        if len(img_files) > max_count:
            max_count = len(img_files)

step = 50
bins = list(range(0, max_count + step, step))
labels = [f"{bins[i]+1}-{bins[i+1]}" for i in range(len(bins)-1)]

# Gom số loài vào từng khoảng
hist = [0] * (len(bins) - 1)
for c in counts:
    for i in range(len(bins) - 1):
        if bins[i] < c <= bins[i+1]:
            hist[i] += 1
            break

plt.bar(labels, hist)
plt.xlabel("Khoảng số lượng ảnh mỗi loài")
plt.ylabel("Số loài")
plt.title("Phân bố số lượng ảnh các loài rắn")
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()
